# %% [markdown]
# # 03 - Model Experiments
# Quick experiments comparing Random Forest vs XGBoost before wiring up `src/train.py`.

# %%
import sys
sys.path.append('..')

from src.train import run_pipeline

model, metrics = run_pipeline()
metrics

# %%
import pandas as pd
fi = pd.read_csv('../artifacts/feature_importance.csv')
fi.plot(kind='barh', x='feature', y='importance', figsize=(8,6))
