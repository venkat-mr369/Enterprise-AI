# %% [markdown]
# # 02 - Feature Engineering
# Prototyping engineered features before promoting them into `src/feature_engineering.py`.

# %%
import sys
sys.path.append('..')

from src.data_ingestion import ingest
from src.preprocessing import preprocess
from src.feature_engineering import add_features

raw = ingest()
processed = preprocess(raw)
featured = add_features(processed)
featured.head()

# %%
featured[['CLV', 'AvgMonthlySpend', 'TenureYears']].describe()

# %%
import seaborn as sns
sns.histplot(featured['AvgMonthlySpend'], kde=True)
